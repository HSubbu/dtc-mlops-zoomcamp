# %%
# !python -V
# Out:
# Python 3.9.12

# %%
# !pip install pyarrow
# Out:
# Requirement already satisfied: pyarrow in /opt/miniconda3/envs/exp-tracking-env/lib/python3.9/site-packages (8.0.0)
# Requirement already satisfied: numpy>=1.16.6 in /opt/miniconda3/envs/exp-tracking-env/lib/python3.9/site-packages (from pyarrow) (1.22.4)

# %%
import pandas as pd

# %%
import pickle

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
from sklearn.feature_extraction import DictVectorizer
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Lasso
from sklearn.linear_model import Ridge

from sklearn.metrics import mean_squared_error

# %%
import mlflow

TRACKING_URI = "sqlite:///mlflow.db"
EXPERIMENT_NAME = "nyc-taxi-experiment"

mlflow.set_tracking_uri(TRACKING_URI)
mlflow.set_experiment(experiment_name=EXPERIMENT_NAME)
# Out:
# <Experiment: artifact_location='./mlruns/1', experiment_id='1', lifecycle_stage='active', name='nyc-taxi-experiment', tags={}>

# %%
def read_dataframe(filename):
    df = pd.read_parquet(filename)

    df.lpep_dropoff_datetime = pd.to_datetime(df.lpep_dropoff_datetime)
    df.lpep_pickup_datetime = pd.to_datetime(df.lpep_pickup_datetime)

    df['duration'] = df.lpep_dropoff_datetime - df.lpep_pickup_datetime
    df.duration = df.duration.apply(lambda td: td.total_seconds() / 60)

    df = df[(df.duration >= 1) & (df.duration <= 60)]

    categorical = ['PULocationID', 'DOLocationID']
    df[categorical] = df[categorical].astype(str)
    
    return df

# %%
df_train = read_dataframe('./data/green_tripdata_2021-01.parquet')
df_val = read_dataframe('./data/green_tripdata_2021-02.parquet')

# %%
len(df_train), len(df_val)
# Out:
# (73908, 61921)

# %%
df_train['PU_DO'] = df_train['PULocationID'] + '_' + df_train['DOLocationID']
df_val['PU_DO'] = df_val['PULocationID'] + '_' + df_val['DOLocationID']

# %%
categorical = ['PU_DO'] #'PULocationID', 'DOLocationID']
numerical = ['trip_distance']

dv = DictVectorizer()

train_dicts = df_train[categorical + numerical].to_dict(orient='records')
X_train = dv.fit_transform(train_dicts)

val_dicts = df_val[categorical + numerical].to_dict(orient='records')
X_val = dv.transform(val_dicts)

# %%
target = 'duration'
y_train = df_train[target].values
y_val = df_val[target].values

# %%
lr = LinearRegression()
lr.fit(X_train, y_train)

y_pred = lr.predict(X_val)

mean_squared_error(y_val, y_pred, squared=False)
# Out:
# 7.758715203911276

# %%
with open('models/lin_reg.bin', 'wb') as f_out:
    pickle.dump((dv, lr), f_out)

# %%
with mlflow.start_run():

    mlflow.set_tag("developer", "Subramanian")

    mlflow.log_param("train-data-path", "./data/green_tripdata_2021-01.csv")
    mlflow.log_param("valid-data-path", "./data/green_tripdata_2021-02.csv")

    alpha = 0.01
    mlflow.log_param("alpha", alpha)
    lr = Lasso(alpha)
    lr.fit(X_train, y_train)

    y_pred = lr.predict(X_val)
    rmse = mean_squared_error(y_val, y_pred, squared=False)
    mlflow.log_metric("rmse", rmse)

    mlflow.log_artifact(local_path="models/lin_reg.bin", artifact_path="models_pickle")

# %% [markdown]
# ## using xgboost model

# %%
import xgboost as xgb

# %%
from hyperopt import fmin, tpe, hp, STATUS_OK, Trials
from hyperopt.pyll import scope

# %%
train = xgb.DMatrix(X_train, label=y_train)
valid = xgb.DMatrix(X_val, label=y_val)

# %%
def objective(params):
    with mlflow.start_run():
        mlflow.set_tag("model", "xgboost")
        mlflow.log_params(params)
        booster = xgb.train(
            params=params,
            dtrain=train,
            num_boost_round=1000,
            evals=[(valid, 'validation')],
            early_stopping_rounds=50
        )
        y_pred = booster.predict(valid)
        rmse = mean_squared_error(y_val, y_pred, squared=False)
        mlflow.log_metric("rmse", rmse)

    return {'loss': rmse, 'status': STATUS_OK}

# %%
search_space = {
    'max_depth': scope.int(hp.quniform('max_depth', 4, 100, 1)),
    'learning_rate': hp.loguniform('learning_rate', -3, 0), # range exp(-3) to exp(0)
    'reg_alpha': hp.loguniform('reg_alpha', -5, -1),
    'reg_lambda': hp.loguniform('reg_lambda', -6, -1),
    'min_child_weight': hp.loguniform('min_child_weight', -1, 3),
    'objective': 'reg:linear',
    'seed': 42
}

best_result = fmin(
    fn=objective,
    space=search_space,
    algo=tpe.suggest,
    max_evals=50,
    trials=Trials()
)
# Out:
# [12:16:10] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	validation-rmse:17.46186
# [1]	validation-rmse:14.61137
# [2]	validation-rmse:12.45140
# [3]	validation-rmse:10.84140
# [4]	validation-rmse:9.66067
# [5]	validation-rmse:8.79984
# [6]	validation-rmse:8.18194
# [7]	validation-rmse:7.74228
# [8]	validation-rmse:7.42691
# [9]	validation-rmse:7.20003
# [10]	validation-rmse:7.03744
# [11]	validation-rmse:6.91606
# [12]	validation-rmse:6.83011
# [13]	validation-rmse:6.76506
# [14]	validation-rmse:6.71955
# [15]	validation-rmse:6.68524
# [16]	validation-rmse:6.65680
# [17]	validation-rmse:6.63584
# [18]	validation-rmse:6.61890
# [19]	validation-rmse:6.60623
# [20]	validation-rmse:6.59567
# [21]	validation-rmse:6.58860
# [22]	validation-rmse:6.58213
# [23]	validation-rmse:6.57654
# [24]	validation-rmse:6.56982
# [25]	validation-rmse:6.56458
# [26]	validation-rmse:6.56121
# [27]	validation-rmse:6.55810
# [28]	validation-rmse:6.55616
# [29]	validation-rmse:6.55348
# [30]	validation-rmse:6.55119
# [31]	validation-rmse:6.54871
# [32]	validation-rmse:6.54719
# [33]	validation-rmse:6.54599
# [34]	validation-rmse:6.54451
# [35]	validation-rmse:6.54247
# [36]	validation-rmse:6.54086
# [37]	validation-rmse:6.53966
# [38]	validation-rmse:6.53704
# [39]	validation-rmse:6.53464
# [40]	validation-rmse:6.53357
# [41]	validation-rmse:6.53247
# [42]	validation-rmse:6.53038
# [43]	validation-rmse:6.52921
# [44]	validation-rmse:6.52813
# [45]	validation-rmse:6.52723
# [46]	validation-rmse:6.52535
# [47]	validation-rmse:6.52458
# [48]	validation-rmse:6.52400
# [49]	validation-rmse:6.52306
# [50]	validation-rmse:6.52218
# [51]	validation-rmse:6.52111
# [52]	validation-rmse:6.52018
# [53]	validation-rmse:6.51833
# [54]	validation-rmse:6.51627
# [55]	validation-rmse:6.51483
# [56]	validation-rmse:6.51421
# [57]	validation-rmse:6.51365
# [58]	validation-rmse:6.51229
# [59]	validation-rmse:6.51178
# [60]	validation-rmse:6.51025
# [61]	validation-rmse:6.51007
# [62]	validation-rmse:6.50882
# [63]	validation-rmse:6.50825
# [64]	validation-rmse:6.50722
# [65]	validation-rmse:6.50599
# [66]	validation-rmse:6.50528
# [67]	validation-rmse:6.50446
# [68]	validation-rmse:6.50370
# [69]	validation-rmse:6.50307
# [70]	validation-rmse:6.50233
# [71]	validation-rmse:6.50132
# [72]	validation-rmse:6.50000
# [73]	validation-rmse:6.49905
# [74]	validation-rmse:6.49834
# [75]	validation-rmse:6.49779
# [76]	validation-rmse:6.49783
# [77]	validation-rmse:6.49730
# [78]	validation-rmse:6.49699
# [79]	validation-rmse:6.49586
# [80]	validation-rmse:6.49513
# [81]	validation-rmse:6.49476
# [82]	validation-rmse:6.49335
# [83]	validation-rmse:6.49260
# [84]	validation-rmse:6.49145
# [85]	validation-rmse:6.49093
# [86]	validation-rmse:6.48979
# [87]	validation-rmse:6.48943
# [88]	validation-rmse:6.48883
# [89]	validation-rmse:6.48819
# [90]	validation-rmse:6.48779
# [91]	validation-rmse:6.48659
# [92]	validation-rmse:6.48584
# [93]	validation-rmse:6.48493
# [94]	validation-rmse:6.48420
# [95]	validation-rmse:6.48412
# [96]	validation-rmse:6.48302
# [97]	validation-rmse:6.48119
# [98]	validation-rmse:6.48043
# [99]	validation-rmse:6.47987
# [100]	validation-rmse:6.47948
# [101]	validation-rmse:6.47849
# [102]	validation-rmse:6.47807
# [103]	validation-rmse:6.47778
# [104]	validation-rmse:6.47725
# [105]	validation-rmse:6.47654
# [106]	validation-rmse:6.47579
# [107]	validation-rmse:6.47544
# [108]	validation-rmse:6.47476
# [109]	validation-rmse:6.47459
# [110]	validation-rmse:6.47377
# [111]	validation-rmse:6.47326
# [112]	validation-rmse:6.47300
# [113]	validation-rmse:6.47192
# [114]	validation-rmse:6.47139
# [115]	validation-rmse:6.47046
# [116]	validation-rmse:6.47017
# [117]	validation-rmse:6.46982
# [118]	validation-rmse:6.46945
# [119]	validation-rmse:6.46893
# [120]	validation-rmse:6.46886
# [121]	validation-rmse:6.46844
# [122]	validation-rmse:6.46781
# [123]	validation-rmse:6.46712
# [124]	validation-rmse:6.46665
# [125]	validation-rmse:6.46613
# [126]	validation-rmse:6.46580
# [127]	validation-rmse:6.46516
# [128]	validation-rmse:6.46427
# [129]	validation-rmse:6.46354
# [130]	validation-rmse:6.46305
# [131]	validation-rmse:6.46228
# [132]	validation-rmse:6.46164
# [133]	validation-rmse:6.46180
# [134]	validation-rmse:6.46164
# [135]	validation-rmse:6.46134
# [136]	validation-rmse:6.46095
# [137]	validation-rmse:6.46029
# [138]	validation-rmse:6.45740
# [139]	validation-rmse:6.45702
# [140]	validation-rmse:6.45678
# [141]	validation-rmse:6.45572
# [142]	validation-rmse:6.45494
# [143]	validation-rmse:6.45448
# [144]	validation-rmse:6.45428
# [145]	validation-rmse:6.45320
# [146]	validation-rmse:6.45340
# [147]	validation-rmse:6.45333
# [148]	validation-rmse:6.45259
# [149]	validation-rmse:6.45210
# [150]	validation-rmse:6.45174
# [151]	validation-rmse:6.45088
# [152]	validation-rmse:6.45066
# [153]	validation-rmse:6.45050
# [154]	validation-rmse:6.45009
# [155]	validation-rmse:6.44971
# [156]	validation-rmse:6.44858
# [157]	validation-rmse:6.44824
# [158]	validation-rmse:6.44785
# [159]	validation-rmse:6.44763
# [160]	validation-rmse:6.44720
# [161]	validation-rmse:6.44622
# [162]	validation-rmse:6.44638
# [163]	validation-rmse:6.44618
# [164]	validation-rmse:6.44566
# [165]	validation-rmse:6.44555
# [166]	validation-rmse:6.44512
# [167]	validation-rmse:6.44484
# [168]	validation-rmse:6.44440
# [169]	validation-rmse:6.44452
# [260]	validation-rmse:6.41862
# [261]	validation-rmse:6.41809
# [262]	validation-rmse:6.41778
# [263]	validation-rmse:6.41737
# [264]	validation-rmse:6.41690
# [265]	validation-rmse:6.41678
# [266]	validation-rmse:6.41660
# [267]	validation-rmse:6.41641
# [268]	validation-rmse:6.41616
# [269]	validation-rmse:6.41620
# [270]	validation-rmse:6.41610
# [271]	validation-rmse:6.41573
# [272]	validation-rmse:6.41582
# [273]	validation-rmse:6.41541
# [274]	validation-rmse:6.41566
# [275]	validation-rmse:6.41537
# [276]	validation-rmse:6.41485
# [277]	validation-rmse:6.41477
# [278]	validation-rmse:6.41450
# [279]	validation-rmse:6.41466
# [280]	validation-rmse:6.41461
# [281]	validation-rmse:6.41465
# [282]	validation-rmse:6.41447
# [283]	validation-rmse:6.41408
# [284]	validation-rmse:6.41375
# [285]	validation-rmse:6.41342
# [286]	validation-rmse:6.41320
# [287]	validation-rmse:6.41327
# [288]	validation-rmse:6.41275
# [289]	validation-rmse:6.41213
# [290]	validation-rmse:6.41209
# [291]	validation-rmse:6.41139
# [292]	validation-rmse:6.41114
# [293]	validation-rmse:6.41128
# [294]	validation-rmse:6.41129
# [295]	validation-rmse:6.41091
# [296]	validation-rmse:6.41042
# [297]	validation-rmse:6.41026
# [298]	validation-rmse:6.41008
# [299]	validation-rmse:6.41053
# [300]	validation-rmse:6.41050
# [301]	validation-rmse:6.41065
# [302]	validation-rmse:6.41035
# [303]	validation-rmse:6.41025
# [304]	validation-rmse:6.40980
# [305]	validation-rmse:6.40978
# [306]	validation-rmse:6.40947
# [307]	validation-rmse:6.40938
# [308]	validation-rmse:6.40936
# [309]	validation-rmse:6.40868
# [310]	validation-rmse:6.40837
# [311]	validation-rmse:6.40805
# [312]	validation-rmse:6.40776
# [313]	validation-rmse:6.40746
# [314]	validation-rmse:6.40730
# [315]	validation-rmse:6.40696
# [316]	validation-rmse:6.40682
# [317]	validation-rmse:6.40667
# [318]	validation-rmse:6.40673
# [319]	validation-rmse:6.40697
# [320]	validation-rmse:6.40667
# [321]	validation-rmse:6.40704
# [322]	validation-rmse:6.40718
# [323]	validation-rmse:6.40709
# [324]	validation-rmse:6.40693
# [325]	validation-rmse:6.40686
# [326]	validation-rmse:6.40680
# [327]	validation-rmse:6.40635
# [328]	validation-rmse:6.40512
# [329]	validation-rmse:6.40508
# [330]	validation-rmse:6.40543
# [331]	validation-rmse:6.40521
# [332]	validation-rmse:6.40503
# [333]	validation-rmse:6.40447
# [334]	validation-rmse:6.40452
# [335]	validation-rmse:6.40409
# [336]	validation-rmse:6.40399
# [337]	validation-rmse:6.40374
# [338]	validation-rmse:6.40319
# [339]	validation-rmse:6.40291
# [340]	validation-rmse:6.40220
# [341]	validation-rmse:6.40176
# [342]	validation-rmse:6.40212
# [343]	validation-rmse:6.40206
# [344]	validation-rmse:6.40175
# [345]	validation-rmse:6.40143
# [346]	validation-rmse:6.40142
# [347]	validation-rmse:6.40132
# [348]	validation-rmse:6.40098
# [349]	validation-rmse:6.40122
# [350]	validation-rmse:6.40117
# [351]	validation-rmse:6.40108
# [352]	validation-rmse:6.40127
# [353]	validation-rmse:6.40127
# [354]	validation-rmse:6.40083
# [355]	validation-rmse:6.40081
# [356]	validation-rmse:6.40057
# [357]	validation-rmse:6.40006
# [358]	validation-rmse:6.39969
# [359]	validation-rmse:6.39936
# [360]	validation-rmse:6.39911
# [361]	validation-rmse:6.39869
# [362]	validation-rmse:6.39840
# [363]	validation-rmse:6.39829
# [364]	validation-rmse:6.39783
# [365]	validation-rmse:6.39718
# [366]	validation-rmse:6.39716
# [367]	validation-rmse:6.39707
# [368]	validation-rmse:6.39713
# [369]	validation-rmse:6.39701
# [370]	validation-rmse:6.39700
# [371]	validation-rmse:6.39649
# [372]	validation-rmse:6.39661
# [373]	validation-rmse:6.39632
# [374]	validation-rmse:6.39618
# [375]	validation-rmse:6.39613
# [376]	validation-rmse:6.39644
# [377]	validation-rmse:6.39643
# [378]	validation-rmse:6.39661
# [379]	validation-rmse:6.39652
# [380]	validation-rmse:6.39621
# [381]	validation-rmse:6.39593
# [382]	validation-rmse:6.39670
# [383]	validation-rmse:6.39661
# [384]	validation-rmse:6.39602
# [385]	validation-rmse:6.39602
# [386]	validation-rmse:6.39628
# [387]	validation-rmse:6.39603
# [388]	validation-rmse:6.39563
# [389]	validation-rmse:6.39537
# [390]	validation-rmse:6.39502
# [391]	validation-rmse:6.39481
# [392]	validation-rmse:6.39508
# [393]	validation-rmse:6.39495
# [394]	validation-rmse:6.39476
# [395]	validation-rmse:6.39470
# [396]	validation-rmse:6.39489
# [397]	validation-rmse:6.39478
# [398]	validation-rmse:6.39464
# [399]	validation-rmse:6.39481
# [400]	validation-rmse:6.39459
# [401]	validation-rmse:6.39432
# [402]	validation-rmse:6.39407
# [403]	validation-rmse:6.39377
# [404]	validation-rmse:6.39374
# [405]	validation-rmse:6.39292
# [406]	validation-rmse:6.39276
# [407]	validation-rmse:6.39322
# [408]	validation-rmse:6.39302
# [409]	validation-rmse:6.39314
# [410]	validation-rmse:6.39309
# [411]	validation-rmse:6.39289
# [412]	validation-rmse:6.39286
# [413]	validation-rmse:6.39278
# [414]	validation-rmse:6.39267
# [415]	validation-rmse:6.39269
# [416]	validation-rmse:6.39252
# [417]	validation-rmse:6.39259
# [418]	validation-rmse:6.39235
# [419]	validation-rmse:6.39238
# [420]	validation-rmse:6.39217
# [421]	validation-rmse:6.39198
# [422]	validation-rmse:6.39118
# [423]	validation-rmse:6.39239
# [424]	validation-rmse:6.39231
# [425]	validation-rmse:6.39201
# [426]	validation-rmse:6.39199
# [427]	validation-rmse:6.39163
# [428]	validation-rmse:6.39239
# [429]	validation-rmse:6.39266
# [430]	validation-rmse:6.39210
# [431]	validation-rmse:6.39209
# [432]	validation-rmse:6.39185
# [433]	validation-rmse:6.39140
# [434]	validation-rmse:6.39124
# [435]	validation-rmse:6.39103
# [436]	validation-rmse:6.39067
# [437]	validation-rmse:6.39061
# [438]	validation-rmse:6.39047
# [439]	validation-rmse:6.39019
# [440]	validation-rmse:6.38993
# [441]	validation-rmse:6.38978
# [714]	validation-rmse:6.38154
# [715]	validation-rmse:6.38163
# [716]	validation-rmse:6.38174
# [717]	validation-rmse:6.38175
# [718]	validation-rmse:6.38178
# [719]	validation-rmse:6.38169
# [720]	validation-rmse:6.38176
# [721]	validation-rmse:6.38199
# [722]	validation-rmse:6.38221
# [723]	validation-rmse:6.38233
# [724]	validation-rmse:6.38239
# [725]	validation-rmse:6.38222
# [12:18:40] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	validation-rmse:20.17917
# [1]	validation-rmse:19.22841
# [2]	validation-rmse:18.33766
# [3]	validation-rmse:17.50384
# [4]	validation-rmse:16.72328
# [5]	validation-rmse:15.99325
# [6]	validation-rmse:15.31140
# [7]	validation-rmse:14.67434
# [8]	validation-rmse:14.07959
# [9]	validation-rmse:13.52562
# [10]	validation-rmse:13.00975
# [11]	validation-rmse:12.52911
# [12]	validation-rmse:12.08210
# [13]	validation-rmse:11.66728
# [14]	validation-rmse:11.28189
# [15]	validation-rmse:10.92472
# [16]	validation-rmse:10.59384
# [17]	validation-rmse:10.28793
# [18]	validation-rmse:10.00461
# [19]	validation-rmse:9.74320
# [20]	validation-rmse:9.50175
# [21]	validation-rmse:9.27892
# [22]	validation-rmse:9.07366
# [23]	validation-rmse:8.88442
# [24]	validation-rmse:8.71018
# [25]	validation-rmse:8.54996
# [26]	validation-rmse:8.40292
# [27]	validation-rmse:8.26784
# [28]	validation-rmse:8.14385
# [29]	validation-rmse:8.02999
# [30]	validation-rmse:7.92554
# [31]	validation-rmse:7.82982
# [32]	validation-rmse:7.74191
# [33]	validation-rmse:7.66122
# [34]	validation-rmse:7.58746
# [35]	validation-rmse:7.51916
# [36]	validation-rmse:7.45682
# [37]	validation-rmse:7.39949
# [38]	validation-rmse:7.34634
# [39]	validation-rmse:7.29746
# [40]	validation-rmse:7.25247
# [41]	validation-rmse:7.21110
# [42]	validation-rmse:7.17317
# [43]	validation-rmse:7.13800
# [44]	validation-rmse:7.10574
# [45]	validation-rmse:7.07612
# [46]	validation-rmse:7.04864
# [47]	validation-rmse:7.02331
# [48]	validation-rmse:6.99999
# [49]	validation-rmse:6.97850
# [50]	validation-rmse:6.95844
# [51]	validation-rmse:6.94017
# [52]	validation-rmse:6.92297
# [53]	validation-rmse:6.90725
# [54]	validation-rmse:6.89243
# [55]	validation-rmse:6.87856
# [56]	validation-rmse:6.86562
# [57]	validation-rmse:6.85366
# [58]	validation-rmse:6.84274
# [59]	validation-rmse:6.83240
# [60]	validation-rmse:6.82283
# [61]	validation-rmse:6.81389
# [62]	validation-rmse:6.80565
# [63]	validation-rmse:6.79769
# [64]	validation-rmse:6.79062
# [65]	validation-rmse:6.78399
# [66]	validation-rmse:6.77746
# [67]	validation-rmse:6.77148
# [68]	validation-rmse:6.76594
# [69]	validation-rmse:6.76075
# [70]	validation-rmse:6.75594
# [71]	validation-rmse:6.75123
# [72]	validation-rmse:6.74660
# [73]	validation-rmse:6.74285
# [74]	validation-rmse:6.73902
# [75]	validation-rmse:6.73522
# [76]	validation-rmse:6.73199
# [77]	validation-rmse:6.72874
# [78]	validation-rmse:6.72593
# [79]	validation-rmse:6.72296
# [80]	validation-rmse:6.72021
# [81]	validation-rmse:6.71778
# [82]	validation-rmse:6.71530
# [83]	validation-rmse:6.71321
# [84]	validation-rmse:6.71077
# [85]	validation-rmse:6.70860
# [86]	validation-rmse:6.70684
# [87]	validation-rmse:6.70483
# [88]	validation-rmse:6.70299
# [89]	validation-rmse:6.70155
# [90]	validation-rmse:6.70000
# [91]	validation-rmse:6.69844
# ...
#      <a href='vscode-notebook-cell:/Users/subramanianhariharan/Documents/kumar_work/mlops/mlops-zoomcamp/02-experiment-tracking/duration-prediction.ipynb#ch0000019?line=10'>11</a> )
#      <a href='vscode-notebook-cell:/Users/subramanianhariharan/Documents/kumar_work/mlops/mlops-zoomcamp/02-experiment-tracking/duration-prediction.ipynb#ch0000019?line=11'>12</a> y_pred = booster.predict(valid)
#      <a href='vscode-notebook-cell:/Users/subramanianhariharan/Documents/kumar_work/mlops/mlops-zoomcamp/02-experiment-tracking/duration-prediction.ipynb#ch0000019?line=12'>13</a> rmse = mean_squared_error(y_val, y_pred, squared=False)
#
# File /opt/miniconda3/envs/exp-tracking-env/lib/python3.9/site-packages/xgboost/core.py:532, in _deprecate_positional_args.<locals>.inner_f(*args, **kwargs)
#     <a href='file:///opt/miniconda3/envs/exp-tracking-env/lib/python3.9/site-packages/xgboost/core.py?line=529'>530</a> for k, arg in zip(sig.parameters, args):
#     <a href='file:///opt/miniconda3/envs/exp-tracking-env/lib/python3.9/site-packages/xgboost/core.py?line=530'>531</a>     kwargs[k] = arg
# --> <a href='file:///opt/miniconda3/envs/exp-tracking-env/lib/python3.9/site-packages/xgboost/core.py?line=531'>532</a> return f(**kwargs)
#
# File /opt/miniconda3/envs/exp-tracking-env/lib/python3.9/site-packages/xgboost/training.py:182, in train(params, dtrain, num_boost_round, evals, obj, feval, maximize, early_stopping_rounds, evals_result, verbose_eval, xgb_model, callbacks, custom_metric)
#     <a href='file:///opt/miniconda3/envs/exp-tracking-env/lib/python3.9/site-packages/xgboost/training.py?line=179'>180</a>         break
#     <a href='file:///opt/miniconda3/envs/exp-tracking-env/lib/python3.9/site-packages/xgboost/training.py?line=180'>181</a>     bst.update(dtrain, i, obj)
# --> <a href='file:///opt/miniconda3/envs/exp-tracking-env/lib/python3.9/site-packages/xgboost/training.py?line=181'>182</a>     if cb_container.after_iteration(bst, i, dtrain, evals):
#     <a href='file:///opt/miniconda3/envs/exp-tracking-env/lib/python3.9/site-packages/xgboost/training.py?line=182'>183</a>         break
#     <a href='file:///opt/miniconda3/envs/exp-tracking-env/lib/python3.9/site-packages/xgboost/training.py?line=184'>185</a> bst = cb_container.after_training(bst)
#
# File /opt/miniconda3/envs/exp-tracking-env/lib/python3.9/site-packages/xgboost/callback.py:246, in CallbackContainer.after_iteration(self, model, epoch, dtrain, evals)
#     <a href='file:///opt/miniconda3/envs/exp-tracking-env/lib/python3.9/site-packages/xgboost/callback.py?line=243'>244</a>     metric_score = [(n, float(s)) for n, s in metric_score_str]
#     <a href='file:///opt/miniconda3/envs/exp-tracking-env/lib/python3.9/site-packages/xgboost/callback.py?line=244'>245</a>     self._update_history(metric_score, epoch)
# --> <a href='file:///opt/miniconda3/envs/exp-tracking-env/lib/python3.9/site-packages/xgboost/callback.py?line=245'>246</a> ret = any(c.after_iteration(model, epoch, self.history)
#     <a href='file:///opt/miniconda3/envs/exp-tracking-env/lib/python3.9/site-packages/xgboost/callback.py?line=246'>247</a>           for c in self.callbacks)
#     <a href='file:///opt/miniconda3/envs/exp-tracking-env/lib/python3.9/site-packages/xgboost/callback.py?line=247'>248</a> return ret
#
# File /opt/miniconda3/envs/exp-tracking-env/lib/python3.9/site-packages/xgboost/callback.py:246, in <genexpr>(.0)
#     <a href='file:///opt/miniconda3/envs/exp-tracking-env/lib/python3.9/site-packages/xgboost/callback.py?line=243'>244</a>     metric_score = [(n, float(s)) for n, s in metric_score_str]
#     <a href='file:///opt/miniconda3/envs/exp-tracking-env/lib/python3.9/site-packages/xgboost/callback.py?line=244'>245</a>     self._update_history(metric_score, epoch)
# --> <a href='file:///opt/miniconda3/envs/exp-tracking-env/lib/python3.9/site-packages/xgboost/callback.py?line=245'>246</a> ret = any(c.after_iteration(model, epoch, self.history)
#     <a href='file:///opt/miniconda3/envs/exp-tracking-env/lib/python3.9/site-packages/xgboost/callback.py?line=246'>247</a>           for c in self.callbacks)
#     <a href='file:///opt/miniconda3/envs/exp-tracking-env/lib/python3.9/site-packages/xgboost/callback.py?line=247'>248</a> return ret
#
# File /opt/miniconda3/envs/exp-tracking-env/lib/python3.9/site-packages/xgboost/callback.py:500, in EvaluationMonitor.after_iteration(self, model, epoch, evals_log)
#     <a href='file:///opt/miniconda3/envs/exp-tracking-env/lib/python3.9/site-packages/xgboost/callback.py?line=496'>497</a> msg += '\n'
#     <a href='file:///opt/miniconda3/envs/exp-tracking-env/lib/python3.9/site-packages/xgboost/callback.py?line=498'>499</a> if (epoch % self.period) == 0 or self.period == 1:
# --> <a href='file:///opt/miniconda3/envs/exp-tracking-env/lib/python3.9/site-packages/xgboost/callback.py?line=499'>500</a>     rabit.tracker_print(msg)
#     <a href='file:///opt/miniconda3/envs/exp-tracking-env/lib/python3.9/site-packages/xgboost/callback.py?line=500'>501</a>     self._latest = None
#     <a href='file:///opt/miniconda3/envs/exp-tracking-env/lib/python3.9/site-packages/xgboost/callback.py?line=501'>502</a> else:
#     <a href='file:///opt/miniconda3/envs/exp-tracking-env/lib/python3.9/site-packages/xgboost/callback.py?line=502'>503</a>     # There is skipped message
#
# File /opt/miniconda3/envs/exp-tracking-env/lib/python3.9/site-packages/xgboost/rabit.py:82, in tracker_print(msg)
#      <a href='file:///opt/miniconda3/envs/exp-tracking-env/lib/python3.9/site-packages/xgboost/rabit.py?line=79'>80</a>     _check_call(_LIB.RabitTrackerPrint(c_str(msg)))
#      <a href='file:///opt/miniconda3/envs/exp-tracking-env/lib/python3.9/site-packages/xgboost/rabit.py?line=80'>81</a> else:
# ---> <a href='file:///opt/miniconda3/envs/exp-tracking-env/lib/python3.9/site-packages/xgboost/rabit.py?line=81'>82</a>     print(msg.strip(), flush=True)
#
# File /opt/miniconda3/envs/exp-tracking-env/lib/python3.9/site-packages/hyperopt/std_out_err_redirect_tqdm.py:22, in DummyTqdmFile.write(self, x)
#      <a href='file:///opt/miniconda3/envs/exp-tracking-env/lib/python3.9/site-packages/hyperopt/std_out_err_redirect_tqdm.py?line=18'>19</a> def write(self, x):
#      <a href='file:///opt/miniconda3/envs/exp-tracking-env/lib/python3.9/site-packages/hyperopt/std_out_err_redirect_tqdm.py?line=19'>20</a>     # Avoid print() second call (useless \n)
#      <a href='file:///opt/miniconda3/envs/exp-tracking-env/lib/python3.9/site-packages/hyperopt/std_out_err_redirect_tqdm.py?line=20'>21</a>     if len(x.rstrip()) > 0:
# ---> <a href='file:///opt/miniconda3/envs/exp-tracking-env/lib/python3.9/site-packages/hyperopt/std_out_err_redirect_tqdm.py?line=21'>22</a>         tqdm.write(x, file=self.file)
#
# File /opt/miniconda3/envs/exp-tracking-env/lib/python3.9/site-packages/tqdm/std.py:617, in tqdm.write(cls, s, file, end, nolock)
#     <a href='file:///opt/miniconda3/envs/exp-tracking-env/lib/python3.9/site-packages/tqdm/std.py?line=614'>615</a> """Print a message via tqdm (without overlap with bars)."""
#     <a href='file:///opt/miniconda3/envs/exp-tracking-env/lib/python3.9/site-packages/tqdm/std.py?line=615'>616</a> fp = file if file is not None else sys.stdout
# --> <a href='file:///opt/miniconda3/envs/exp-tracking-env/lib/python3.9/site-packages/tqdm/std.py?line=616'>617</a> with cls.external_write_mode(file=file, nolock=nolock):
#     <a href='file:///opt/miniconda3/envs/exp-tracking-env/lib/python3.9/site-packages/tqdm/std.py?line=617'>618</a>     # Write the message
#     <a href='file:///opt/miniconda3/envs/exp-tracking-env/lib/python3.9/site-packages/tqdm/std.py?line=618'>619</a>     fp.write(s)
#     <a href='file:///opt/miniconda3/envs/exp-tracking-env/lib/python3.9/site-packages/tqdm/std.py?line=619'>620</a>     fp.write(end)
#
# File /opt/miniconda3/envs/exp-tracking-env/lib/python3.9/contextlib.py:119, in _GeneratorContextManager.__enter__(self)
#     <a href='file:///opt/miniconda3/envs/exp-tracking-env/lib/python3.9/contextlib.py?line=116'>117</a> del self.args, self.kwds, self.func
#     <a href='file:///opt/miniconda3/envs/exp-tracking-env/lib/python3.9/contextlib.py?line=117'>118</a> try:
# --> <a href='file:///opt/miniconda3/envs/exp-tracking-env/lib/python3.9/contextlib.py?line=118'>119</a>     return next(self.gen)
#     <a href='file:///opt/miniconda3/envs/exp-tracking-env/lib/python3.9/contextlib.py?line=119'>120</a> except StopIteration:
#     <a href='file:///opt/miniconda3/envs/exp-tracking-env/lib/python3.9/contextlib.py?line=120'>121</a>     raise RuntimeError("generator didn't yield") from None
#
# File /opt/miniconda3/envs/exp-tracking-env/lib/python3.9/site-packages/tqdm/std.py:642, in tqdm.external_write_mode(cls, file, nolock)
#     <a href='file:///opt/miniconda3/envs/exp-tracking-env/lib/python3.9/site-packages/tqdm/std.py?line=635'>636</a> for inst in getattr(cls, '_instances', []):
#     <a href='file:///opt/miniconda3/envs/exp-tracking-env/lib/python3.9/site-packages/tqdm/std.py?line=636'>637</a>     # Clear instance if in the target output file
#     <a href='file:///opt/miniconda3/envs/exp-tracking-env/lib/python3.9/site-packages/tqdm/std.py?line=637'>638</a>     # or if write output + tqdm output are both either
#     <a href='file:///opt/miniconda3/envs/exp-tracking-env/lib/python3.9/site-packages/tqdm/std.py?line=638'>639</a>     # sys.stdout or sys.stderr (because both are mixed in terminal)
#     <a href='file:///opt/miniconda3/envs/exp-tracking-env/lib/python3.9/site-packages/tqdm/std.py?line=639'>640</a>     if hasattr(inst, "start_t") and (inst.fp == fp or all(
#     <a href='file:///opt/miniconda3/envs/exp-tracking-env/lib/python3.9/site-packages/tqdm/std.py?line=640'>641</a>             f in (sys.stdout, sys.stderr) for f in (fp, inst.fp))):
# --> <a href='file:///opt/miniconda3/envs/exp-tracking-env/lib/python3.9/site-packages/tqdm/std.py?line=641'>642</a>         inst.clear(nolock=True)
#     <a href='file:///opt/miniconda3/envs/exp-tracking-env/lib/python3.9/site-packages/tqdm/std.py?line=642'>643</a>         inst_cleared.append(inst)
#     <a href='file:///opt/miniconda3/envs/exp-tracking-env/lib/python3.9/site-packages/tqdm/std.py?line=643'>644</a> yield
#
# File /opt/miniconda3/envs/exp-tracking-env/lib/python3.9/site-packages/tqdm/std.py:1334, in tqdm.clear(self, nolock)
#    <a href='file:///opt/miniconda3/envs/exp-tracking-env/lib/python3.9/site-packages/tqdm/std.py?line=1331'>1332</a>     self.moveto(pos)
#    <a href='file:///opt/miniconda3/envs/exp-tracking-env/lib/python3.9/site-packages/tqdm/std.py?line=1332'>1333</a>     self.sp('')
# -> <a href='file:///opt/miniconda3/envs/exp-tracking-env/lib/python3.9/site-packages/tqdm/std.py?line=1333'>1334</a>     self.fp.write('\r')  # place cursor back at the beginning of line
#    <a href='file:///opt/miniconda3/envs/exp-tracking-env/lib/python3.9/site-packages/tqdm/std.py?line=1334'>1335</a>     self.moveto(-pos)
#    <a href='file:///opt/miniconda3/envs/exp-tracking-env/lib/python3.9/site-packages/tqdm/std.py?line=1335'>1336</a> if not nolock:
#
# File /opt/miniconda3/envs/exp-tracking-env/lib/python3.9/site-packages/tqdm/utils.py:145, in DisableOnWriteError.disable_on_exception.<locals>.inner(*args, **kwargs)
#     <a href='file:///opt/miniconda3/envs/exp-tracking-env/lib/python3.9/site-packages/tqdm/utils.py?line=142'>143</a> def inner(*args, **kwargs):
#     <a href='file:///opt/miniconda3/envs/exp-tracking-env/lib/python3.9/site-packages/tqdm/utils.py?line=143'>144</a>     try:
# --> <a href='file:///opt/miniconda3/envs/exp-tracking-env/lib/python3.9/site-packages/tqdm/utils.py?line=144'>145</a>         return func(*args, **kwargs)
#     <a href='file:///opt/miniconda3/envs/exp-tracking-env/lib/python3.9/site-packages/tqdm/utils.py?line=145'>146</a>     except OSError as e:
#     <a href='file:///opt/miniconda3/envs/exp-tracking-env/lib/python3.9/site-packages/tqdm/utils.py?line=146'>147</a>         if e.errno != 5:
#
# File /opt/miniconda3/envs/exp-tracking-env/lib/python3.9/site-packages/ipykernel/iostream.py:562, in OutStream.write(self, string)
#     <a href='file:///opt/miniconda3/envs/exp-tracking-env/lib/python3.9/site-packages/ipykernel/iostream.py?line=559'>560</a>         self.pub_thread.schedule(self._flush)
#     <a href='file:///opt/miniconda3/envs/exp-tracking-env/lib/python3.9/site-packages/ipykernel/iostream.py?line=560'>561</a>     else:
# --> <a href='file:///opt/miniconda3/envs/exp-tracking-env/lib/python3.9/site-packages/ipykernel/iostream.py?line=561'>562</a>         self._schedule_flush()
#     <a href='file:///opt/miniconda3/envs/exp-tracking-env/lib/python3.9/site-packages/ipykernel/iostream.py?line=563'>564</a> return len(string)
#
# File /opt/miniconda3/envs/exp-tracking-env/lib/python3.9/site-packages/ipykernel/iostream.py:468, in OutStream._schedule_flush(self)
#     <a href='file:///opt/miniconda3/envs/exp-tracking-env/lib/python3.9/site-packages/ipykernel/iostream.py?line=464'>465</a> def _schedule_in_thread():
#     <a href='file:///opt/miniconda3/envs/exp-tracking-env/lib/python3.9/site-packages/ipykernel/iostream.py?line=465'>466</a>     self._io_loop.call_later(self.flush_interval, self._flush)
# --> <a href='file:///opt/miniconda3/envs/exp-tracking-env/lib/python3.9/site-packages/ipykernel/iostream.py?line=467'>468</a> self.pub_thread.schedule(_schedule_in_thread)
#
# File /opt/miniconda3/envs/exp-tracking-env/lib/python3.9/site-packages/ipykernel/iostream.py:217, in IOPubThread.schedule(self, f)
#     <a href='file:///opt/miniconda3/envs/exp-tracking-env/lib/python3.9/site-packages/ipykernel/iostream.py?line=214'>215</a>     self._events.append(f)
#     <a href='file:///opt/miniconda3/envs/exp-tracking-env/lib/python3.9/site-packages/ipykernel/iostream.py?line=215'>216</a>     # wake event thread (message content is ignored)
# --> <a href='file:///opt/miniconda3/envs/exp-tracking-env/lib/python3.9/site-packages/ipykernel/iostream.py?line=216'>217</a>     self._event_pipe.send(b"")
#     <a href='file:///opt/miniconda3/envs/exp-tracking-env/lib/python3.9/site-packages/ipykernel/iostream.py?line=217'>218</a> else:
#     <a href='file:///opt/miniconda3/envs/exp-tracking-env/lib/python3.9/site-packages/ipykernel/iostream.py?line=218'>219</a>     f()
#
# File /opt/miniconda3/envs/exp-tracking-env/lib/python3.9/site-packages/zmq/sugar/socket.py:615, in Socket.send(self, data, flags, copy, track, routing_id, group)
#     <a href='file:///opt/miniconda3/envs/exp-tracking-env/lib/python3.9/site-packages/zmq/sugar/socket.py?line=607'>608</a>         data = zmq.Frame(
#     <a href='file:///opt/miniconda3/envs/exp-tracking-env/lib/python3.9/site-packages/zmq/sugar/socket.py?line=608'>609</a>             data,
#     <a href='file:///opt/miniconda3/envs/exp-tracking-env/lib/python3.9/site-packages/zmq/sugar/socket.py?line=609'>610</a>             track=track,
#     <a href='file:///opt/miniconda3/envs/exp-tracking-env/lib/python3.9/site-packages/zmq/sugar/socket.py?line=610'>611</a>             copy=copy or None,
#     <a href='file:///opt/miniconda3/envs/exp-tracking-env/lib/python3.9/site-packages/zmq/sugar/socket.py?line=611'>612</a>             copy_threshold=self.copy_threshold,
#     <a href='file:///opt/miniconda3/envs/exp-tracking-env/lib/python3.9/site-packages/zmq/sugar/socket.py?line=612'>613</a>         )
#     <a href='file:///opt/miniconda3/envs/exp-tracking-env/lib/python3.9/site-packages/zmq/sugar/socket.py?line=613'>614</a>     data.group = group
# --> <a href='file:///opt/miniconda3/envs/exp-tracking-env/lib/python3.9/site-packages/zmq/sugar/socket.py?line=614'>615</a> return super().send(data, flags=flags, copy=copy, track=track)
#
# File zmq/backend/cython/socket.pyx:740, in zmq.backend.cython.socket.Socket.send()
#
# File zmq/backend/cython/socket.pyx:787, in zmq.backend.cython.socket.Socket.send()
#
# File zmq/backend/cython/socket.pyx:244, in zmq.backend.cython.socket._send_copy()
#
# File /opt/miniconda3/envs/exp-tracking-env/lib/python3.9/site-packages/zmq/backend/cython/checkrc.pxd:13, in zmq.backend.cython.checkrc._check_rc()
#
# KeyboardInterrupt:

# %%
mlflow.xgboost.autolog(disable=True)

# %%
with mlflow.start_run():
    
    train = xgb.DMatrix(X_train, label=y_train)
    valid = xgb.DMatrix(X_val, label=y_val)

    best_params = {
        'learning_rate': 0.09585355369315604,
        'max_depth': 30,
        'min_child_weight': 1.060597050922164,
        'objective': 'reg:linear',
        'reg_alpha': 0.018060244040060163,
        'reg_lambda': 0.011658731377413597,
        'seed': 42
    }

    mlflow.log_params(best_params)

    booster = xgb.train(
        params=best_params,
        dtrain=train,
        num_boost_round=10,
        evals=[(valid, 'validation')],
        early_stopping_rounds=50
    )

    y_pred = booster.predict(valid)
    rmse = mean_squared_error(y_val, y_pred, squared=False)
    mlflow.log_metric("rmse", rmse)

    with open("models/preprocessor.b", "wb") as f_out:
        pickle.dump(dv, f_out)
    mlflow.log_artifact("models/preprocessor.b", artifact_path="preprocessor")

    mlflow.xgboost.log_model(booster, artifact_path="models_mlflow")
# Out:
# [10:19:10] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	validation-rmse:19.48425
# [1]	validation-rmse:17.95634
# [2]	validation-rmse:16.59114
# [3]	validation-rmse:15.37412
# [4]	validation-rmse:14.29011
# [5]	validation-rmse:13.32800
# [6]	validation-rmse:12.47570
# [7]	validation-rmse:11.72140
# [8]	validation-rmse:11.05888
# [9]	validation-rmse:10.47583

# %%
import mlflow
logged_model = 'runs:/1943e2c603bf4073a0c54760f47befe7/models_mlflow'

# Load model as a PyFuncModel.
loaded_model = mlflow.pyfunc.load_model(logged_model)
# Out:
# [12:10:57] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.

# %%
loaded_model
# Out:
# mlflow.pyfunc.loaded_model:
#   artifact_path: models_mlflow
#   flavor: mlflow.xgboost
#   run_id: 1943e2c603bf4073a0c54760f47befe7

# %%
xgboost_model = mlflow.xgboost.load_model(logged_model)
# Out:
# [12:13:20] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.

# %%
xgboost_model

# %%
y_pred = xgboost_model.predict(valid)

# %%
y_pred[:5]
# Out:
# array([11.090618,  4.70716 , 13.853971, 15.741649,  6.238872],
#       dtype=float32)

# %%
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor, ExtraTreesRegressor
from sklearn.svm import LinearSVR

mlflow.sklearn.autolog()

for model_class in (RandomForestRegressor, GradientBoostingRegressor, ExtraTreesRegressor, LinearSVR):

    with mlflow.start_run():

        mlflow.log_param("train-data-path", "./data/green_tripdata_2021-01.csv")
        mlflow.log_param("valid-data-path", "./data/green_tripdata_2021-02.csv")
        mlflow.log_artifact("models/preprocessor.b", artifact_path="preprocessor")

        mlmodel = model_class()
        mlmodel.fit(X_train, y_train)

        y_pred = mlmodel.predict(X_val)
        rmse = mean_squared_error(y_val, y_pred, squared=False)
        mlflow.log_metric("rmse", rmse)
# Out:
# /Users/cristian.martinez/miniconda3/envs/exp-tracking-env/lib/python3.9/site-packages/sklearn/svm/_base.py:1206: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
